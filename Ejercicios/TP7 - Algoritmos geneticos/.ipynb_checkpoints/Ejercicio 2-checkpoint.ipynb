# %% [markdown]
# ## Problema del viajante
#
# Resolver el problema del viajante utilizando algoritmos genéticos.
#
# - ¿Es posible aproximarse al resultado?

# %% [markdown]
# ## Codificación
#
# - Definir como se codificará el problema

# %% [markdown]
# ## Adaptación
#
# - Definir como se calculará la adaptación de un individuo
# - ¿Existen estados que deben ser penalizados?

# %%
import numpy
import random
import matplotlib
import matplotlib.pyplot as plt

def generar_poblacion(num_pop):
    poblacion = numpy.zeros(shape=(num_pop, 10))
    for i in range(0, num_pop): 
        poblacion[i] = numpy.random.permutation([i for i in range(1,11)])
    
    return poblacion.astype(int)

def calc_km(individuo):
    ciudades = [
                            [0, 188, 70.1, 84.8, 72.7, 54.5, 36.4, 18.9, 8.7, 50.7, 37.6],
                            [188, 0, 199, 214, 108, 184, 162, 148, 134, 186, 99.1],
                            [70.1, 251, 0, 14.9, 136, 16.9, 60.8, 51.2, 70.2, 41.2, 100],
                            [84.8, 266, 14.9, 0, 150, 31.5, 75.5, 65.9, 84.8, 48.3, 115],
                            [72.7, 108, 135, 150, 0, 120, 97.4, 84, 69.7, 122, 35],
                            [54.5, 184, 16.9, 31.5, 120, 0, 45.2, 35.6, 54.4, 47.2, 84.7],
                            [36.4, 162, 60.8, 75.5, 97.4, 45.2, 0, 18.8, 30.2, 52.8, 62.5],
                            [18.9, 148, 51.2, 65.8, 64.2, 35.6, 18.8, 0, 18.9, 43, 49.1],
                            [8.7, 134, 70.2, 84.8, 69.7, 54.4, 30.2, 18.9, 0, 56.4, 34.7],
                            [50.7, 186, 41.2, 48.1, 122, 47.2, 52.8, 43, 56.4, 0, 86.6],
                            [37.6, 99.1,100, 115, 35.1, 84.7, 62.5, 49.1, 34.7, 86.6, 0]
                ]

    ciudades2 = [
            "San Rafael", 
            "El Sosneado", 
            "Jaime Prats", 
            "Gral Alvear", 
            "El Nihuil", 
            "Villa Atuel", 
            "Las Malvinas", 
            "Salto de las Rosas",
            "Rama Caida",
            "Monte Coman",
            "Rincon del Atuel" ]
    
    #Calcular km recorridos
    km = 0

    #Se agrega san rafael al principio y al final del recorrido
    individuo = numpy.insert(individuo, 0, 0)
    individuo = numpy.append(individuo, 0)

    i=0
    
    #Se recorren las ciudades del recorrido
    for item2 in range(len(individuo)-1):
        #se suman las distancias
        km = km + ciudades[individuo[i]][individuo[i+1]]
        i=i+1
        
    return km
    

#equation_inputs : valores de entrada
#pop : población
def cal_pop_fitness(population):
    fitness = []
    
    ciudades = [
                            [0, 188, 70.1, 84.8, 72.7, 54.5, 36.4, 18.9, 8.7, 50.7, 37.6],
                            [188, 0, 199, 214, 108, 184, 162, 148, 134, 186, 99.1],
                            [70.1, 251, 0, 14.9, 136, 16.9, 60.8, 51.2, 70.2, 41.2, 100],
                            [84.8, 266, 14.9, 0, 150, 31.5, 75.5, 65.9, 84.8, 48.3, 115],
                            [72.7, 108, 135, 150, 0, 120, 97.4, 84, 69.7, 122, 35],
                            [54.5, 184, 16.9, 31.5, 120, 0, 45.2, 35.6, 54.4, 47.2, 84.7],
                            [36.4, 162, 60.8, 75.5, 97.4, 45.2, 0, 18.8, 30.2, 52.8, 62.5],
                            [18.9, 148, 51.2, 65.8, 64.2, 35.6, 18.8, 0, 18.9, 43, 49.1],
                            [8.7, 134, 70.2, 84.8, 69.7, 54.4, 30.2, 18.9, 0, 56.4, 34.7],
                            [50.7, 186, 41.2, 48.1, 122, 47.2, 52.8, 43, 56.4, 0, 86.6],
                            [37.6, 99.1,100, 115, 35.1, 84.7, 62.5, 49.1, 34.7, 86.6, 0]
                ]

    ciudades2 = [
            "San Rafael", 
            "El Sosneado", 
            "Jaime Prats", 
            "Gral Alvear", 
            "El Nihuil", 
            "Villa Atuel", 
            "Las Malvinas", 
            "Salto de las Rosas",
            "Rama Caida",
            "Monte Coman",
            "Rincon del Atuel" ]
    
    #Se recorre la poblacion 
    for pop in population:
        #penalizar ciudades repetidas
        penalizar=False
        if len(pop) != len(set(pop)):
            penalizar=True 
        
        #Calcular km recorridos
        km = 0
        
        #Se agrega san rafael al principio y al final del recorrido
        pop = numpy.insert(pop, 0, 0)
        pop = numpy.append(pop, 0)
        i=0  
        #Se recorren las ciudades del recorrido
        for item2 in range(len(pop)-1):
            #se suman las distancias
            km = km + ciudades[pop[i]][pop[i+1]]
            i=i+1
        
        #Aplicar la inversa (adaptacion)
        adaptacion=1/km  
        
        if penalizar:
            adaptacion=adaptacion*-9999999 
        
        fitness.append(adaptacion)
    
    return fitness

# %% [markdown]
# ## Selección

# %%
#pop: población
#fitness: arreglo con los valores de adaptación
#num_parent: cantidad de padres que se quieren obtener
def select_mating_pool(pop, fitness, num_parents):
    ranking = [0] * len(fitness)
    prob = []
    
    for rank in range(len(fitness), 0, -1):
        #indice de mayor valor
        ranking[fitness.index(max(fitness))] = rank
        fitness[fitness.index(max(fitness))] = -99999999
    
    for i in range(0, len(ranking)):
        prob.append(ranking[i] / (len(ranking) * (len(ranking) - 1 )))
    
    prob = numpy.array(prob)
    prob /= prob.sum()
    parents = numpy.random.choice(pop.shape[0], size = num_parents,  p = prob)
    lista = [pop[indice] for indice in parents]
    return lista

# %% [markdown]
# ## Cruza

# %%
def arreglar_gen(hijo):
    if len(hijo) != len(set(hijo)):
        hijo = list(set(hijo))
        res = list(set([i for i in range(1,11)]) - set(hijo))
        for i in res:
            hijo.append(i)
    return hijo

#parents: lista de padres
#offspring_size: cantidad de hijos que se quieren obtener
def crossover(parents, offspring_size):    
    
    lista = [2, 3, 4, 5, 6, 7, 8, 9]
    offspring1 = []
    offspring2 = []
    
    #Generar arreglo vacío donde se guardarán los hijos
    offspring = []
    
    #Definir punto de cruce en la mitad de los padre 
    crossover_point = numpy.sort(numpy.array(random.sample(lista, 2)))
    
    for k in range(0, offspring_size, 2):
        # Índice del primer padre para realizar la cruza
        parent1_idx = k%parents.shape[0]
        # Índice del segundo padre para realizar la cruza
        parent2_idx = (k+1)%parents.shape[0]
        # Generar la primera parte del primer hijo
        offspring1[0:crossover_point[0]] = parents[parent1_idx, 0:crossover_point[0]]
        # Generar la segunda parte del primer hijo
        offspring1[crossover_point[0]:] = parents[parent2_idx, crossover_point[0]:crossover_point[1]]
        # Generar la tercera parte del primer hijo
        offspring1[crossover_point[1]:] = parents[parent1_idx, crossover_point[1]:]
        # Generar la primera parte del segundo hijo
        offspring2[0:crossover_point[0]] = parents[parent2_idx, 0:crossover_point[0]]
        # Generar la segunda parte del segundo hijo
        offspring2[crossover_point[0]:] = parents[parent1_idx, crossover_point[0]:crossover_point[1]]
        # Generar la tercera parte del segundo hijo
        offspring2[crossover_point[1]:] = parents[parent2_idx, crossover_point[1]:]
        
        offspring.append(arreglar_gen(offspring1))
        offspring.append(arreglar_gen(offspring2))
    
    #Devolver lista de hijos
    return offspring

# %% [markdown]
# ## Mutación

# %%
#offspring_crossover: lista de hijos a mutar
def mutation(offspring_crossover):
    #print("Offspring Crossover: ", offspring_crossover)
    listapos = [i for i in range(0,len(offspring_crossover[0]))]
    
    for idx in range(len(offspring_crossover)):
        replacepos = random.sample(listapos, 2)
        
        # Reemplazar el valor de dos genes por dos valores aleatorios
        aux = offspring_crossover[idx][min(replacepos)] 
        offspring_crossover[idx][min(replacepos)] = offspring_crossover[idx][max(replacepos)]
        offspring_crossover[idx][max(replacepos)] = aux
    
    #Devolver lista de hijos mutados
    return offspring_crossover

# %% [markdown]
# # Algoritmo

# %%
#Cantidad de genes
num_genes = 10
#Soluciones por población
sol_per_pop = 200
#Número de padres para cruza
num_parents_mating = 20
#Tamaño de la población
pop_size = (sol_per_pop, num_genes)
#Crear pobliación inicial con valores aleatorios
new_population = generar_poblacion(sol_per_pop)
#Cantidad de generaciones a realizar
num_generations = 200

# %%
gen = []
fit = []
best_adaptation = 0
best_match = []

for generation in range(num_generations):
    # Obtener valores de adaptación de la población
    fitness = cal_pop_fitness(new_population)
    # Selección
    parents = select_mating_pool(new_population, fitness, num_parents_mating)
    parents = numpy.array(parents)
    
    # Cruza
    offspring_crossover = crossover(parents, offspring_size=(pop_size[0] - parents.shape[0]))
    
    # Mutación
    offspring_mutation = mutation(offspring_crossover)
    offspring_mutation = numpy.array(offspring_mutation)
    
    # Crear nueva población basada en los padres y los hijos
    new_population[0:parents.shape[0], :] = parents
    new_population[parents.shape[0]:, :] = offspring_mutation

    # Obtener mejor resultado para la generación
    fit.append(numpy.max(cal_pop_fitness(new_population)))
    print("Adaptación:",numpy.max(cal_pop_fitness(new_population)))
    gen.append(generation)
    print("Generación:",generation)
    
    if best_adaptation < numpy.max(cal_pop_fitness(new_population)):
        best_adaptation = numpy.max(cal_pop_fitness(new_population))
        best_match_idx = numpy.where(cal_pop_fitness(new_population) == numpy.max(cal_pop_fitness(new_population)))
        best_match = new_population[best_match_idx, :]
        print(new_population[best_match_idx, :])

#Obtener la mejor solución
print("Mejor resultado : ", best_match)
print("Adaptación del mejor resultado : ", best_adaptation)
print("KM Recorridos", calc_km(best_match))

#Gráfico
fig, ax = plt.subplots()
ax.plot(gen, fit, 'b')
ax.set_ylabel('Fitness')
ax.set_xlabel('Generation')
plt.show()
# Out:
# Adaptación: 0.001866716445771887
# Generación: 0
# [[[ 9  2  3  5  6  7  8 10  1  4]]]
# Adaptación: 0.0017790428749332855
# Generación: 1
# Adaptación: 0.0017790428749332855
# Generación: 2
# Adaptación: 0.001607200257152041
# Generación: 3
# Adaptación: 0.0017790428749332855
# Generación: 4
# Adaptación: 0.0017790428749332855
# Generación: 5
# Adaptación: 0.0015429717636167258
# Generación: 6
# Adaptación: 0.0017790428749332855
# Generación: 7
# Adaptación: 0.0013933398355858992
# Generación: 8
# Adaptación: 0.0017790428749332855
# Generación: 9
# Adaptación: 0.0017790428749332855
# Generación: 10
# Adaptación: 0.0017790428749332855
# Generación: 11
# Adaptación: 0.0013989927252378287
# Generación: 12
# Adaptación: 0.0014328700386874909
# Generación: 13
# Adaptación: 0.0016123831022250886
# Generación: 14
# Adaptación: 0.0016123831022250886
# Generación: 15
# Adaptación: 0.0013838915029061722
# Generación: 16
# Adaptación: 0.0017304031839418584
# Generación: 17
# Adaptación: 0.0017790428749332855
# Generación: 18
# Adaptación: 0.0017790428749332855
# Generación: 19
# Adaptación: 0.0015248551387618174
# Generación: 20
# Adaptación: 0.0015384615384615387
# Generación: 21
# Adaptación: 0.001607200257152041
# Generación: 22
# Adaptación: 0.0014492753623188406
# Generación: 23
# Adaptación: 0.0016069419893941827
# Generación: 24
# Adaptación: 0.0013966480446927373
# Generación: 25
# Adaptación: 0.0014492753623188406
# Generación: 26
# Adaptación: 0.0016162922256343945
# Generación: 27
# Adaptación: 0.0015309246785058174
# Generación: 28
# Adaptación: 0.0017790428749332855
# Generación: 29
# Adaptación: 0.0017790428749332855
# Generación: 30
# Adaptación: 0.0017790428749332855
# Generación: 31
# Adaptación: 0.0014204545454545453
# Generación: 32
# Adaptación: 0.0017790428749332855
# Generación: 33
# Adaptación: 0.0017307026652821048
# Generación: 34
# Adaptación: 0.0016079755587715067
# Generación: 35
# Adaptación: 0.0015262515262515265
# Generación: 36
# Adaptación: 0.0017099863201094393
# Generación: 37
# Adaptación: 0.0017099863201094393
# Generación: 38
# Adaptación: 0.0017790428749332855
# Generación: 39
# Adaptación: 0.0016123831022250886
# Generación: 40
# Adaptación: 0.0014448779078167894
# Generación: 41
# Adaptación: 0.0014448779078167894
# Generación: 42
# Adaptación: 0.0014448779078167894
# Generación: 43
# Adaptación: 0.0017790428749332855
# Generación: 44
# Adaptación: 0.0015012760846719712
# Generación: 45
# Adaptación: 0.0013933398355858992
# Generación: 46
# Adaptación: 0.001432459533018192
# Generación: 47
# Adaptación: 0.001535155050660117
# Generación: 48
# Adaptación: 0.001432459533018192
# Generación: 49
# Adaptación: 0.0016778523489932886
# Generación: 50
# Adaptación: 0.0017790428749332855
# Generación: 51
# Adaptación: 0.001432459533018192
# Generación: 52
# Adaptación: 0.001432459533018192
# Generación: 53
# Adaptación: 0.0017790428749332855
# Generación: 54
# Adaptación: 0.0017790428749332855
# Generación: 55
# Adaptación: 0.001866716445771887
# Generación: 56
# Adaptación: 0.0014492753623188406
# Generación: 57
# Adaptación: 0.001432459533018192
# Generación: 58
# Adaptación: 0.0016369291209690619
# Generación: 59
# Adaptación: 0.0016369291209690619
# Generación: 60
# Adaptación: 0.0016369291209690619
# Generación: 61
# Adaptación: 0.0014492753623188406
# Generación: 62
# Adaptación: 0.0017790428749332855
# Generación: 63
# Adaptación: 0.0016719612104999163
# Generación: 64
# Adaptación: 0.0017790428749332855
# Generación: 65
# Adaptación: 0.001432459533018192
# Generación: 66
# Adaptación: 0.0016781339150864236
# Generación: 67
# Adaptación: 0.001866716445771887
# Generación: 68
# Adaptación: 0.0015262515262515265
# Generación: 69
# Adaptación: 0.0014604936468526361
# Generación: 70
# Adaptación: 0.0017099863201094393
# Generación: 71
# Adaptación: 0.0014547570555717194
# Generación: 72
# Adaptación: 0.0014351320321469574
# Generación: 73
# Adaptación: 0.0017790428749332855
# Generación: 74
# Adaptación: 0.0014114326040931544
# Generación: 75
# Adaptación: 0.0017790428749332855
# Generación: 76
# Adaptación: 0.0014204545454545453
# Generación: 77
# Adaptación: 0.001432459533018192
# Generación: 78
# Adaptación: 0.0017790428749332855
# Generación: 79
# Adaptación: 0.0015506280043417584
# Generación: 80
# Adaptación: 0.001866716445771887
# Generación: 81
# Adaptación: 0.0017790428749332855
# Generación: 82
# Adaptación: 0.0014204545454545453
# Generación: 83
# Adaptación: 0.0017790428749332855
# Generación: 84
# Adaptación: 0.001383508577753182
# Generación: 85
# Adaptación: 0.0014492753623188406
# Generación: 86
# Adaptación: 0.0016719612104999163
# Generación: 87
# Adaptación: 0.0016702856188408216
# Generación: 88
# Adaptación: 0.0017790428749332855
# Generación: 89
# Adaptación: 0.0016244314489928524
# Generación: 90
# Adaptación: 0.0017307026652821048
# Generación: 91
# Adaptación: 0.0016812373907195697
# Generación: 92
# Adaptación: 0.001432459533018192
# Generación: 93
# Adaptación: 0.0013993842709207947
# Generación: 94
# Adaptación: 0.0017790428749332855
# Generación: 95
# Adaptación: 0.0017790428749332855
# Generación: 96
# Adaptación: 0.0017790428749332855
# Generación: 97
# Adaptación: 0.0014351320321469574
# Generación: 98
# Adaptación: 0.0016069419893941827
# Generación: 99
# Adaptación: 0.0015559358954411078
# Generación: 100
# Adaptación: 0.0017304031839418584
# Generación: 101
# Adaptación: 0.0017304031839418584
# Generación: 102
# Adaptación: 0.0017304031839418584
# Generación: 103
# Adaptación: 0.0014492753623188406
# Generación: 104
# Adaptación: 0.0014492753623188406
# Generación: 105
# Adaptación: 0.0014156285390713474
# Generación: 106
# Adaptación: 0.0015429717636167258
# Generación: 107
# Adaptación: 0.0016342539630658606
# Generación: 108
# Adaptación: 0.0016342539630658606
# Generación: 109
# Adaptación: 0.0015429717636167258
# Generación: 110
# Adaptación: 0.0017790428749332855
# Generación: 111
# Adaptación: 0.0017790428749332855
# Generación: 112
# Adaptación: 0.0017790428749332855
# Generación: 113
# Adaptación: 0.0017790428749332855
# Generación: 114
# Adaptación: 0.0015360983102918587
# Generación: 115
# Adaptación: 0.001487652484379649
# Generación: 116
# Adaptación: 0.0015693659761456373
# Generación: 117
# Adaptación: 0.0017790428749332855
# Generación: 118
# Adaptación: 0.0014492753623188406
# Generación: 119
# Adaptación: 0.0017790428749332855
# Generación: 120
# Adaptación: 0.0013989927252378287
# Generación: 121
# Adaptación: 0.0015693659761456373
# Generación: 122
# Adaptación: 0.001487652484379649
# Generación: 123
# Adaptación: 0.0015015015015015015
# Generación: 124
# Adaptación: 0.0016812373907195697
# Generación: 125
# Adaptación: 0.001607200257152041
# Generación: 126
# Adaptación: 0.0014641288433382138
# Generación: 127
# Adaptación: 0.0016702856188408216
# Generación: 128
# Adaptación: 0.0014114326040931544
# Generación: 129
# Adaptación: 0.001432459533018192
# Generación: 130
# Adaptación: 0.0015262515262515265
# Generación: 131
# Adaptación: 0.0015959144589849986
# Generación: 132
# Adaptación: 0.0014490653528474136
# Generación: 133
# Adaptación: 0.0017790428749332855
# Generación: 134
# Adaptación: 0.0014490653528474136
# Generación: 135
# Adaptación: 0.0015262515262515265
# Generación: 136
# Adaptación: 0.0016812373907195697
# Generación: 137
# Adaptación: 0.001432459533018192
# Generación: 138
# Adaptación: 0.0014492753623188406
# Generación: 139
# Adaptación: 0.0017790428749332855
# Generación: 140
# Adaptación: 0.0016244314489928528
# Generación: 141
# Adaptación: 0.0015262515262515265
# Generación: 142
# Adaptación: 0.0015262515262515265
# Generación: 143
# Adaptación: 0.0014277555682467161
# Generación: 144
# Adaptación: 0.0017790428749332855
# Generación: 145
# Adaptación: 0.001607200257152041
# Generación: 146
# Adaptación: 0.0014351320321469574
# Generación: 147
# Adaptación: 0.0014351320321469574
# Generación: 148
# Adaptación: 0.0014204545454545453
# Generación: 149
# Adaptación: 0.0017790428749332855
# Generación: 150
# Adaptación: 0.001628929793125916
# Generación: 151
# Adaptación: 0.0017790428749332855
# Generación: 152
# Adaptación: 0.0017790428749332855
# Generación: 153
# Adaptación: 0.001487652484379649
# Generación: 154
# Adaptación: 0.001607200257152041
# Generación: 155
# Adaptación: 0.0016719612104999163
# Generación: 156
# Adaptación: 0.0014204545454545453
# Generación: 157
# Adaptación: 0.0016299918500407495
# Generación: 158
# Adaptación: 0.0015262515262515265
# Generación: 159
# Adaptación: 0.0015262515262515265
# Generación: 160
# Adaptación: 0.001432459533018192
# Generación: 161
# Adaptación: 0.0015429717636167258
# Generación: 162
# Adaptación: 0.0015429717636167258
# Generación: 163
# Adaptación: 0.0016069419893941827
# Generación: 164
# Adaptación: 0.0017790428749332855
# Generación: 165
# Adaptación: 0.001432459533018192
# Generación: 166
# Adaptación: 0.001432459533018192
# Generación: 167
# Adaptación: 0.0016719612104999163
# Generación: 168
# Adaptación: 0.0017790428749332855
# Generación: 169
# Adaptación: 0.0017790428749332855
# Generación: 170
# Adaptación: 0.0016069419893941827
# Generación: 171
# Adaptación: 0.0013933398355858992
# Generación: 172
# Adaptación: 0.0013933398355858992
# Generación: 173
# Adaptación: 0.001607200257152041
# Generación: 174
# Adaptación: 0.001607200257152041
# Generación: 175
# Adaptación: 0.001383508577753182
# Generación: 176
# Adaptación: 0.0017307026652821048
# Generación: 177
# Adaptación: 0.0014492753623188406
# Generación: 178
# Adaptación: 0.0014492753623188406
# Generación: 179
# Adaptación: 0.0017790428749332855
# Generación: 180
# Adaptación: 0.0017790428749332855
# Generación: 181
# Adaptación: 0.0015429717636167258
# Generación: 182
# Adaptación: 0.0014604936468526361
# Generación: 183
# Adaptación: 0.0015012760846719712
# Generación: 184
# Adaptación: 0.0015693659761456373
# Generación: 185
# Adaptación: 0.001412628902387343
# Generación: 186
# Adaptación: 0.0015415446277169723
# Generación: 187
# Adaptación: 0.0013993842709207947
# Generación: 188
# Adaptación: 0.0017790428749332855
# Generación: 189
# Adaptación: 0.0017790428749332855
# Generación: 190
# Adaptación: 0.0016812373907195697
# Generación: 191
# Adaptación: 0.0016812373907195697
# Generación: 192
# Adaptación: 0.0016812373907195697
# Generación: 193
# Adaptación: 0.0016215339711366952
# Generación: 194
# Adaptación: 0.0016215339711366952
# Generación: 195
# Adaptación: 0.0015959144589849986
# Generación: 196
# Adaptación: 0.0017307026652821048
# Generación: 197
# Adaptación: 0.0017307026652821048
# Generación: 198
# Adaptación: 0.001432459533018192
# Generación: 199
# Mejor resultado :  [[[ 9  2  3  5  6  7  8 10  1  4]]]
# Adaptación del mejor resultado :  0.001866716445771887
# KM Recorridos 535.7
