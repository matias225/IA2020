# %% [markdown]
# # El problema de la mochila
#
# Se tiene una mochila y un conjunto de artículos con diferente peso y valor. Se intenta determinar que artículos se pueden colocar adentro de la mochila de manera que no se sobrepase el límite de peso de la mochila maximizando el valor total.
#
# Resolver el problema agregando heurística para los siguientes artículos y un límite de 30kg:
#
# <table style="font-size:16px">
#     <tr>
#         <th>Item</th><td>Valor</td><td>Peso</td>
#     </tr>
#     <tr>
#         <th>A</th><td>4</td><td>12</td>
#     </tr>
#     <tr>
#         <th>B</th><td>2</td><td>2</td>
#     </tr>
#     <tr>
#         <th>C</th><td>10</td><td>4</td>
#     </tr>
#     <tr>
#         <th>D</th><td>1</td><td>1</td>
#     </tr>
#     <tr>
#         <th>E</th><td>5</td><td>15</td>
#     </tr>
#     <tr>
#         <th>F</th><td>3</td><td>2</td>
#     </tr>
#     <tr>
#         <th>G</th><td>14</td><td>7</td>
#     </tr>
#     <tr>
#         <th>H</th><td>4</td><td>10</td>
#     </tr>
# </table>

# %% [markdown]
# ## Codificación
#
# - Definir como se codificará el problema

# %% [markdown]
# ## Adaptación
#
# - Definir como se calculará la adaptación de un individuo
# - ¿Existen estados que deben ser penalizados?

# %%
import numpy
import random
import matplotlib
import matplotlib.pyplot as plt

def generar_poblacion(num_pop):
    poblacion = numpy.zeros(shape=(num_pop, 8))
    
    for i in range(0, num_pop): 
        poblacion[i] = numpy.random.permutation([i for i in range(0,8)])
    
    return poblacion.astype(int)

#equation_inputs: valores de entrada
#pop: población
def cal_pop_fitness(population):
    fitness = []
    articulos = ["A", "B", "C", "D", "E", "F", "G", "H", "Vacio"]
    pesos = [12, 2, 4, 1, 15, 2, 7, 10, 0]
    valores = [4, 2, 10, 1, 5, 3, 14, 4, 0]
    
    for pop in population:
        #penalizar ciudades repetidas
        penalizar = False
        
        kg = 0
        valor = 0
        rvp = 0
        i = 0
        
        #se recorren los articulos
        for item2 in range(len(pop)-1):
            #se suman las relaciones valor peso
            kg = kg + pesos[pop[i]]
            valor = valor + valores[pop[i]]
            i=i+1
        
        rvp = valor/kg
        
        #aplicar la inversa (adaptacion)
        adaptacion= 1/rvp  
        
        if len(pop) != len(set(pop)) or kg > 30:
            adaptacion = adaptacion * -9999999 
            
        fitness.append(adaptacion)
    return fitness

# %% [markdown]
# ## Selección

# %%
#pop: población
#fitness: arreglo con los valores de adaptación
#num_parent: cantidad de padres que se quieren obtener
def select_mating_pool(pop, fitness, num_parents):
    ranking = [0] * len(fitness)
    prob = []
    
    for rank in range(len(fitness), 0, -1):
        #indice de mayor valor
        ranking[fitness.index(max(fitness))] = rank
        fitness[fitness.index(max(fitness))] = -99999999
    
    for i in range(0, len(ranking)):
        prob.append(ranking[i] / (len(ranking) * (len(ranking) - 1 )))
    
    prob = numpy.array(prob)
    prob /= prob.sum()
    parents = numpy.random.choice(pop.shape[0], size = num_parents,  p = prob)
    lista = [pop[indice] for indice in parents]
    return lista

# %% [markdown]
# ## Cruza

# %%
def arreglar_gen(hijo):
    if len(hijo) != len(set(hijo)):
        hijo = list(set(hijo))
        res = list(set([i for i in range(1,11)]) - set(hijo))
        for i in res:
            hijo.append(i)
    return hijo

#parents: lista de padres
#offspring_size: cantidad de hijos que se quieren obtener
def crossover(parents, offspring_size):    
    
    lista = [2, 3, 4, 5, 6, 7]
    offspring1 = []
    offspring2 = []
    
    #Generar arreglo vacío donde se guardarán los hijos
    offspring = []
    
    #Definir punto de cruce en la mitad de los padre 
    crossover_point = numpy.sort(numpy.array(random.sample(lista, 2)))
    
    for k in range(0, offspring_size, 2):
        # Índice del primer padre para realizar la cruza
        parent1_idx = k%parents.shape[0]
        # Índice del segundo padre para realizar la cruza
        parent2_idx = (k+1)%parents.shape[0]
        # Generar la primera parte del primer hijo
        offspring1[0:crossover_point[0]] = parents[parent1_idx, 0:crossover_point[0]]
        # Generar la segunda parte del primer hijo
        offspring1[crossover_point[0]:] = parents[parent2_idx, crossover_point[0]:crossover_point[1]]
        # Generar la tercera parte del primer hijo
        offspring1[crossover_point[1]:] = parents[parent1_idx, crossover_point[1]:]
        # Generar la primera parte del segundo hijo
        offspring2[0:crossover_point[0]] = parents[parent2_idx, 0:crossover_point[0]]
        # Generar la segunda parte del segundo hijo
        offspring2[crossover_point[0]:] = parents[parent1_idx, crossover_point[0]:crossover_point[1]]
        # Generar la tercera parte del segundo hijo
        offspring2[crossover_point[1]:] = parents[parent2_idx, crossover_point[1]:]
        
        offspring.append(offspring1)
        offspring.append(offspring2)
    
    #Devolver lista de hijos
    return offspring

# %% [markdown]
# ## Mutación

# %%
#offspring_crossover: lista de hijos a mutar
def mutation(offspring_crossover):
    #print("Offspring Crossover: ", offspring_crossover)
    listapos = [i for i in range(0,len(offspring_crossover[0]))]
    
    for idx in range(len(offspring_crossover)):
        replacepos = random.sample(listapos, 2)
        
        # Reemplazar el valor de dos genes por dos valores aleatorios
        aux = offspring_crossover[idx][min(replacepos)] 
        offspring_crossover[idx][min(replacepos)] = offspring_crossover[idx][max(replacepos)]
        offspring_crossover[idx][max(replacepos)] = aux
    
    #Devolver lista de hijos mutados
    return offspring_crossover

# %% [markdown]
# # Algoritmo

# %%
#Cantidad de genes
num_genes = 10
#Soluciones por población
sol_per_pop = 200
#Número de padres para cruza
num_parents_mating = 20
#Tamaño de la población
pop_size = (sol_per_pop, num_genes)
#Crear pobliación inicial con valores aleatorios
new_population = generar_poblacion(sol_per_pop)
#Cantidad de generaciones a realizar
num_generations = 200

# %%
gen = []
fit = []
best_adaptation = -99999999
best_match = []

for generation in range(num_generations):
    # Obtener valores de adaptación de la población
    fitness = cal_pop_fitness(new_population)
    
    # Selección
    parents = select_mating_pool(new_population, fitness, num_parents_mating)
    parents = numpy.array(parents)
    
    # Cruza
    offspring_crossover = crossover(parents, offspring_size=(pop_size[0] - parents.shape[0]))
    
    # Mutación
    offspring_mutation = mutation(offspring_crossover)
    offspring_mutation = numpy.array(offspring_mutation)
    
    # Crear nueva población basada en los padres y los hijos
    new_population[0:parents.shape[0], :] = parents
    new_population[parents.shape[0]:, :] = offspring_mutation

    # Obtener mejor resultado para la generación
    fit.append(numpy.max(cal_pop_fitness(new_population)))
    print("Adaptación:",numpy.max(cal_pop_fitness(new_population)))
    gen.append(generation)
    print("Generación:",generation)
    
    if best_adaptation < numpy.max(cal_pop_fitness(new_population)):
        best_adaptation = numpy.max(cal_pop_fitness(new_population))
        best_match_idx = numpy.where(cal_pop_fitness(new_population) == numpy.max(cal_pop_fitness(new_population)))
        best_match = new_population[best_match_idx, :]

#Obtener la mejor solución
print("Mejor resultado: ", best_match)
print("Adaptación del mejor resultado: ", best_adaptation)

#Gráfico
fig, ax = plt.subplots()
ax.plot(gen, fit, 'b')
ax.set_ylabel('Fitness')
ax.set_xlabel('Generation')
plt.show()


print("La poblacion inicial se deberia generar de forma distinta para que existan población con menos de 30 kg.")
# Out:
# Adaptación: -9999999.0
# Generación: 0
# Adaptación: -8723403.382978724
# Generación: 1
# Adaptación: -8723403.382978724
# Generación: 2
# Adaptación: -8723403.382978724
# Generación: 3
# Adaptación: -10243901.414634146
# Generación: 4
# Adaptación: -11020407.061224489
# Generación: 5
# Adaptación: -10294116.61764706
# Generación: 6
# Adaptación: -10294116.61764706
# Generación: 7
# Adaptación: -10294116.61764706
# Generación: 8
# Adaptación: -9705881.38235294
# Generación: 9
# Adaptación: -9705881.38235294
# Generación: 10
# Adaptación: -9705881.38235294
# Generación: 11
# Adaptación: -9705881.38235294
# Generación: 12
# Adaptación: -7741934.709677419
# Generación: 13
# Adaptación: -7741934.709677419
# Generación: 14
# Adaptación: -7741934.709677419
# Generación: 15
# Adaptación: -7931033.689655172
# Generación: 16
# Adaptación: -7931033.689655172
# Generación: 17
# Adaptación: -7931033.689655172
# Generación: 18
# Adaptación: -7741934.709677419
# Generación: 19
# Adaptación: -7741934.709677419
# Generación: 20
# Adaptación: -7368420.315789473
# Generación: 21
# Adaptación: -7368420.315789473
# Generación: 22
# Adaptación: -7368420.315789473
# Generación: 23
# Adaptación: -9024389.341463415
# Generación: 24
# Adaptación: -7959182.87755102
# Generación: 25
# Adaptación: -7959182.87755102
# Generación: 26
# Adaptación: -5263157.368421053
# Generación: 27
# Adaptación: -5263157.368421053
# Generación: 28
# Adaptación: -5263157.368421053
# Generación: 29
# Adaptación: -6170212.14893617
# Generación: 30
# Adaptación: -6170212.14893617
# Generación: 31
# Adaptación: -5714285.142857143
# Generación: 32
# Adaptación: -5714285.142857143
# Generación: 33
# Adaptación: -5714285.142857143
# Generación: 34
# Adaptación: -5714285.142857143
# Generación: 35
# Adaptación: -5714285.142857143
# Generación: 36
# Adaptación: -5312499.46875
# Generación: 37
# Adaptación: -3999999.6
# Generación: 38
# Adaptación: -3999999.6
# Generación: 39
# Adaptación: -3999999.6
# Generación: 40
# Adaptación: -3999999.6
# Generación: 41
# Adaptación: -3999999.6
# Generación: 42
# Adaptación: -3999999.6
# Generación: 43
# Adaptación: -5312499.46875
# Generación: 44
# Adaptación: -3999999.6
# Generación: 45
# Adaptación: -3999999.6
# Generación: 46
# Adaptación: -3999999.6
# Generación: 47
# Adaptación: -3999999.6
# Generación: 48
# Adaptación: -3999999.6
# Generación: 49
# Adaptación: -3999999.6
# Generación: 50
# Adaptación: -3999999.6
# Generación: 51
# Adaptación: -3999999.6
# Generación: 52
# Adaptación: -3999999.6
# Generación: 53
# Adaptación: -3999999.6
# Generación: 54
# Adaptación: -3999999.6
# Generación: 55
# Adaptación: -3999999.6
# Generación: 56
# Adaptación: -3999999.6
# Generación: 57
# Adaptación: -3999999.6
# Generación: 58
# Adaptación: -3999999.6
# Generación: 59
# Adaptación: -3999999.6
# Generación: 60
# Adaptación: -3999999.6
# Generación: 61
# Adaptación: -3999999.6
# Generación: 62
# Adaptación: -3999999.6
# Generación: 63
# Adaptación: -3999999.6
# Generación: 64
# Adaptación: -3999999.6
# Generación: 65
# Adaptación: -3999999.6
# Generación: 66
# Adaptación: -3999999.6
# Generación: 67
# Adaptación: -3999999.6
# Generación: 68
# Adaptación: -3999999.6
# Generación: 69
# Adaptación: -3999999.6
# Generación: 70
# Adaptación: -3999999.6
# Generación: 71
# Adaptación: -3999999.6
# Generación: 72
# Adaptación: -3999999.6
# Generación: 73
# Adaptación: -3999999.6
# Generación: 74
# Adaptación: -3999999.6
# Generación: 75
# Adaptación: -3999999.6
# Generación: 76
# Adaptación: -3999999.6
# Generación: 77
# Adaptación: -3999999.6
# Generación: 78
# Adaptación: -3999999.6
# Generación: 79
# Adaptación: -3999999.6
# Generación: 80
# Adaptación: -3999999.6
# Generación: 81
# Adaptación: -3999999.6
# Generación: 82
# Adaptación: -3999999.6
# Generación: 83
# Adaptación: -3999999.6
# Generación: 84
# Adaptación: -3999999.6
# Generación: 85
# Adaptación: -3999999.6
# Generación: 86
# Adaptación: -3999999.6
# Generación: 87
# Adaptación: -3999999.6
# Generación: 88
# Adaptación: -3999999.6
# Generación: 89
# Adaptación: -3999999.6
# Generación: 90
# Adaptación: -3999999.6
# Generación: 91
# Adaptación: -3999999.6
# Generación: 92
# Adaptación: -3999999.6
# Generación: 93
# Adaptación: -3999999.6
# Generación: 94
# Adaptación: -3999999.6
# Generación: 95
# Adaptación: -3999999.6
# Generación: 96
# Adaptación: -3999999.6
# Generación: 97
# Adaptación: -3999999.6
# Generación: 98
# Adaptación: -3999999.6
# Generación: 99
# Adaptación: -3999999.6
# Generación: 100
# Adaptación: -3999999.6
# Generación: 101
# Adaptación: -3999999.6
# Generación: 102
# Adaptación: -3999999.6
# Generación: 103
# Adaptación: -3999999.6
# Generación: 104
# Adaptación: -3999999.6
# Generación: 105
# Adaptación: -3999999.6
# Generación: 106
# Adaptación: -3999999.6
# Generación: 107
# Adaptación: -3999999.6
# Generación: 108
# Adaptación: -3999999.6
# Generación: 109
# Adaptación: -3999999.6
# Generación: 110
# Adaptación: -3999999.6
# Generación: 111
# Adaptación: -3999999.6
# Generación: 112
# Adaptación: -3999999.6
# Generación: 113
# Adaptación: -3999999.6
# Generación: 114
# Adaptación: -3999999.6
# Generación: 115
# Adaptación: -3999999.6
# Generación: 116
# Adaptación: -3999999.6
# Generación: 117
# Adaptación: -3999999.6
# Generación: 118
# Adaptación: -3999999.6
# Generación: 119
# Adaptación: -3999999.6
# Generación: 120
# Adaptación: -3999999.6
# Generación: 121
# Adaptación: -3999999.6
# Generación: 122
# Adaptación: -3999999.6
# Generación: 123
# Adaptación: -3999999.6
# Generación: 124
# Adaptación: -3999999.6
# Generación: 125
# Adaptación: -3999999.6
# Generación: 126
# Adaptación: -3999999.6
# Generación: 127
# Adaptación: -3999999.6
# Generación: 128
# Adaptación: -3999999.6
# Generación: 129
# Adaptación: -3999999.6
# Generación: 130
# Adaptación: -3999999.6
# Generación: 131
# Adaptación: -3999999.6
# Generación: 132
# Adaptación: -3999999.6
# Generación: 133
# Adaptación: -3999999.6
# Generación: 134
# Adaptación: -3999999.6
# Generación: 135
# Adaptación: -3999999.6
# Generación: 136
# Adaptación: -3999999.6
# Generación: 137
# Adaptación: -3999999.6
# Generación: 138
# Adaptación: -3999999.6
# Generación: 139
# Adaptación: -3999999.6
# Generación: 140
# Adaptación: -3999999.6
# Generación: 141
# Adaptación: -3999999.6
# Generación: 142
# Adaptación: -3999999.6
# Generación: 143
# Adaptación: -3999999.6
# Generación: 144
# Adaptación: -3999999.6
# Generación: 145
# Adaptación: -3999999.6
# Generación: 146
# Adaptación: -3999999.6
# Generación: 147
# Adaptación: -3999999.6
# Generación: 148
# Adaptación: -3999999.6
# Generación: 149
# Adaptación: -3999999.6
# Generación: 150
# Adaptación: -3999999.6
# Generación: 151
# Adaptación: -3999999.6
# Generación: 152
# Adaptación: -3999999.6
# Generación: 153
# Adaptación: -3999999.6
# Generación: 154
# Adaptación: -3999999.6
# Generación: 155
# Adaptación: -3999999.6
# Generación: 156
# Adaptación: -3999999.6
# Generación: 157
# Adaptación: -3999999.6
# Generación: 158
# Adaptación: -3999999.6
# Generación: 159
# Adaptación: -3999999.6
# Generación: 160
# Adaptación: -3999999.6
# Generación: 161
# Adaptación: -3999999.6
# Generación: 162
# Adaptación: -3999999.6
# Generación: 163
# Adaptación: -3999999.6
# Generación: 164
# Adaptación: -3999999.6
# Generación: 165
# Adaptación: -3999999.6
# Generación: 166
# Adaptación: -3999999.6
# Generación: 167
# Adaptación: -3999999.6
# Generación: 168
# Adaptación: -3999999.6
# Generación: 169
# Adaptación: -3999999.6
# Generación: 170
# Adaptación: -3999999.6
# Generación: 171
# Adaptación: -3999999.6
# Generación: 172
# Adaptación: -3999999.6
# Generación: 173
# Adaptación: -3999999.6
# Generación: 174
# Adaptación: -3999999.6
# Generación: 175
# Adaptación: -3999999.6
# Generación: 176
# Adaptación: -3999999.6
# Generación: 177
# Adaptación: -3999999.6
# Generación: 178
# Adaptación: -3999999.6
# Generación: 179
# Adaptación: -3999999.6
# Generación: 180
# Adaptación: -3999999.6
# Generación: 181
# Adaptación: -3999999.6
# Generación: 182
# Adaptación: -3999999.6
# Generación: 183
# Adaptación: -3999999.6
# Generación: 184
# Adaptación: -3999999.6
# Generación: 185
# Adaptación: -3999999.6
# Generación: 186
# Adaptación: -3999999.6
# Generación: 187
# Adaptación: -3999999.6
# Generación: 188
# Adaptación: -3999999.6
# Generación: 189
# Adaptación: -3999999.6
# Generación: 190
# Adaptación: -3999999.6
# Generación: 191
# Adaptación: -3999999.6
# Generación: 192
# Adaptación: -3999999.6
# Generación: 193
# Adaptación: -3999999.6
# Generación: 194
# Adaptación: -3999999.6
# Generación: 195
# Adaptación: -3999999.6
# Generación: 196
# Adaptación: -3999999.6
# Generación: 197
# Adaptación: -3999999.6
# Generación: 198
# Adaptación: -3999999.6
# Generación: 199
# Mejor resultado:  [[[2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]
#   [2 2 2 2 2 2 2 2]]]
# Adaptación del mejor resultado:  -3999999.6
# La poblacion inicial se deberia generar de forma distinta para que existan poblacion con menos de 30 kg.
